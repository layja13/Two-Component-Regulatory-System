# %%
# %pip install mesa
# Out:
# Collecting mesa
#   Downloading mesa-2.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from mesa) (8.1.7)
# Collecting cookiecutter (from mesa)
#   Downloading cookiecutter-2.6.0-py3-none-any.whl (39 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mesa) (3.7.1)
# Collecting mesa-viz-tornado>=0.1.3,~=0.1.0 (from mesa)
#   Downloading Mesa_Viz_Tornado-0.1.3-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 22.4 MB/s eta 0:00:00
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from mesa) (3.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mesa) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mesa) (2.0.3)
# Collecting solara (from mesa)
#   Downloading solara-1.32.0-py2.py3-none-any.whl (5.7 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mesa) (4.66.2)
# Requirement already satisfied: tornado in /usr/local/lib/python3.10/dist-packages (from mesa-viz-tornado>=0.1.3,~=0.1.0->mesa) (6.3.3)
# Collecting binaryornot>=0.4.4 (from cookiecutter->mesa)
#   Downloading binaryornot-0.4.4-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: Jinja2<4.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from cookiecutter->mesa) (3.1.3)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from cookiecutter->mesa) (6.0.1)
# Requirement already satisfied: python-slugify>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from cookiecutter->mesa) (8.0.4)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from cookiecutter->mesa) (2.31.0)
# Collecting arrow (from cookiecutter->mesa)
#   Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from cookiecutter->mesa) (13.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mesa) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mesa) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mesa) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mesa) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mesa) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mesa) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mesa) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mesa) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mesa) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mesa) (2024.1)
# Collecting solara-server[dev,starlette]==1.32.0 (from solara->mesa)
#   Downloading solara_server-1.32.0-py2.py3-none-any.whl (3.9 kB)
# Collecting solara-ui[all]==1.32.0 (from solara->mesa)
#   Downloading solara_ui-1.32.0-py2.py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 56.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from solara-server[dev,starlette]==1.32.0->solara->mesa) (3.13.4)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from solara-server[dev,starlette]==1.32.0->solara->mesa) (5.5.6)
# Collecting jupyter-client>=7.0.0 (from solara-server[dev,starlette]==1.32.0->solara->mesa)
#   Downloading jupyter_client-8.6.1-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.9/105.9 kB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from solara-server[dev,starlette]==1.32.0->solara->mesa) (5.10.4)
# Collecting rich-click (from solara-server[dev,starlette]==1.32.0->solara->mesa)
#   Downloading rich_click-1.7.4-py3-none-any.whl (32 kB)
# Collecting watchdog (from solara-server[dev,starlette]==1.32.0->solara->mesa)
#   Downloading watchdog-4.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 8.4 MB/s eta 0:00:00
# Collecting watchfiles (from solara-server[dev,starlette]==1.32.0->solara->mesa)
#   Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.8 MB/s eta 0:00:00
# Collecting starlette (from solara-server[dev,starlette]==1.32.0->solara->mesa)
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 8.7 MB/s eta 0:00:00
# Collecting uvicorn (from solara-server[dev,starlette]==1.32.0->solara->mesa)
#   Downloading uvicorn-0.29.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 7.2 MB/s eta 0:00:00
# Collecting websockets (from solara-server[dev,starlette]==1.32.0->solara->mesa)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 14.1 MB/s eta 0:00:00
# Requirement already satisfied: humanize in /usr/local/lib/python3.10/dist-packages (from solara-ui[all]==1.32.0->solara->mesa) (4.7.0)
# Collecting ipyvue>=1.9.0 (from solara-ui[all]==1.32.0->solara->mesa)
#   Downloading ipyvue-1.11.0-py2.py3-none-any.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 63.1 MB/s eta 0:00:00
# Collecting ipyvuetify>=1.6.10 (from solara-ui[all]==1.32.0->solara->mesa)
#   Downloading ipyvuetify-1.9.4-py2.py3-none-any.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 73.4 MB/s eta 0:00:00
# Requirement already satisfied: ipywidgets>=7.7 in /usr/local/lib/python3.10/dist-packages (from solara-ui[all]==1.32.0->solara->mesa) (7.7.1)
# Collecting reacton>=1.7.1 (from solara-ui[all]==1.32.0->solara->mesa)
#   Downloading reacton-1.8.3-py2.py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.9/107.9 kB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: chardet>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from binaryornot>=0.4.4->cookiecutter->mesa) (5.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2<4.0.0,>=2.7->cookiecutter->mesa) (2.1.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mesa) (1.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify>=4.0.0->cookiecutter->mesa) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->cookiecutter->mesa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->cookiecutter->mesa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->cookiecutter->mesa) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->cookiecutter->mesa) (2024.2.2)
# Collecting types-python-dateutil>=2.8.10 (from arrow->cookiecutter->mesa)
#   Downloading types_python_dateutil-2.9.0.20240316-py3-none-any.whl (9.7 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->cookiecutter->mesa) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->cookiecutter->mesa) (2.16.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (3.0.10)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=7.0.0->solara-server[dev,starlette]==1.32.0->solara->mesa) (5.7.2)
# Requirement already satisfied: pyzmq>=23.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=7.0.0->solara-server[dev,starlette]==1.32.0->solara->mesa) (23.2.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->cookiecutter->mesa) (0.1.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from reacton>=1.7.1->solara-ui[all]==1.32.0->solara->mesa) (4.11.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->solara-server[dev,starlette]==1.32.0->solara->mesa) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->solara-server[dev,starlette]==1.32.0->solara->mesa) (4.19.2)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from solara-ui[all]==1.32.0->solara->mesa) (5.3.3)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from solara-ui[all]==1.32.0->solara->mesa) (3.6)
# Collecting pymdown-extensions (from solara-ui[all]==1.32.0->solara->mesa)
#   Downloading pymdown_extensions-10.8-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.8/250.8 kB 24.1 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette->solara-server[dev,starlette]==1.32.0->solara->mesa) (3.7.1)
# Collecting h11>=0.8 (from uvicorn->solara-server[dev,starlette]==1.32.0->solara->mesa)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette->solara-server[dev,starlette]==1.32.0->solara->mesa) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette->solara-server[dev,starlette]==1.32.0->solara->mesa) (1.2.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 66.2 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (3.0.43)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->solara-server[dev,starlette]==1.32.0->solara->mesa) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->solara-server[dev,starlette]==1.32.0->solara->mesa) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->solara-server[dev,starlette]==1.32.0->solara->mesa) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->solara-server[dev,starlette]==1.32.0->solara->mesa) (0.18.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=7.0.0->solara-server[dev,starlette]==1.32.0->solara->mesa) (4.2.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (6.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (0.8.4)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (23.1.0)
# Collecting jupyter-client>=7.0.0 (from solara-server[dev,starlette]==1.32.0->solara->mesa)
#   Downloading jupyter_client-7.4.9-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 15.2 MB/s eta 0:00:00
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (0.20.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (1.0.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=7.0.0->solara-server[dev,starlette]==1.32.0->solara->mesa) (0.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (0.2.13)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (0.2.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (0.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (1.2.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (21.2.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (1.7.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui[all]==1.32.0->solara->mesa) (2.22)
# Installing collected packages: websockets, watchdog, types-python-dateutil, pymdown-extensions, mesa-viz-tornado, jedi, h11, binaryornot, watchfiles, uvicorn, starlette, jupyter-client, arrow, rich-click, cookiecutter, reacton, ipyvue, ipyvuetify, solara-ui, solara-server, solara, mesa
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
# Successfully installed arrow-1.3.0 binaryornot-0.4.4 cookiecutter-2.6.0 h11-0.14.0 ipyvue-1.11.0 ipyvuetify-1.9.4 jedi-0.19.1 jupyter-client-7.4.9 mesa-2.3.0 mesa-viz-tornado-0.1.3 pymdown-extensions-10.8 reacton-1.8.3 rich-click-1.7.4 solara-1.32.0 solara-server-1.32.0 solara-ui-1.32.0 starlette-0.37.2 types-python-dateutil-2.9.0.20240316 uvicorn-0.29.0 watchdog-4.0.0 watchfiles-0.21.0 websockets-12.0

# %%
from mesa import Agent, Model
from mesa.space import MultiGrid
from mesa.time import RandomActivation
from mesa.datacollection import DataCollector
from mesa.visualization.modules import CanvasGrid
from mesa.visualization.ModularVisualization import ModularServer
from mesa.visualization.modules import ChartModule
import math
import numpy as np
import matplotlib.pyplot as plt
from multiprocessing import Pool

# %% [markdown]
# # Functions to collect information

# %%
def get_fitness_avg(model):
    agent_fitness = [agent.fitness for agent in model.schedule.agents if isinstance(agent, Cell)]
    return np.mean(agent_fitness) if agent_fitness else 0

def get_fitness_std(model):
    agent_fitness = [agent.fitness for agent in model.schedule.agents if isinstance(agent, Cell)]
    return np.std(agent_fitness) if agent_fitness else 0

def get_life_avg(model):
    agent_lives = [agent.time_alive for agent in model.schedule.agents if isinstance(agent, Cell)]
    return np.mean(agent_lives) if agent_lives else 0

def get_life_std(model):
    agent_lives = [agent.time_alive for agent in model.schedule.agents if isinstance(agent, Cell)]
    return np.std(agent_lives) if agent_lives else 0

def get_offspring_avg(model):
    agent_offspring = [agent.num_offspring for agent in model.schedule.agents if isinstance(agent, Cell)]
    return np.mean(agent_offspring) if agent_offspring else 0

def get_offspring_std(model):
    agent_offspring = [agent.num_offspring for agent in model.schedule.agents if isinstance(agent, Cell)]
    return np.std(agent_offspring) if agent_offspring else 0

def get_fertility_avg(model):
    agent_fertility = [agent.fertility for agent in model.schedule.agents if isinstance(agent, Cell)]
    return np.mean(agent_fertility) if agent_fertility else 0

def get_fertility_std(model):
    agent_fertility = [agent.fertility for agent in model.schedule.agents if isinstance(agent, Cell)]
    return np.std(agent_fertility) if agent_fertility else 0

def save_best_controller(model):
    best_fitness = -float('inf')
    best_controller = None
    for cell in model.schedule.agents:
        if isinstance(cell, Cell) and cell.fitness > best_fitness:
            best_fitness = cell.fitness
            best_controller = cell.get_controller_state()
    return best_controller

# %% [markdown]
# # Model

# %%
# Glucose Source
class Glucose(Agent):
    def __init__(self, unique_id, model, x, y, amount_of_calories):
        super().__init__(unique_id, model)
        self.pos = (x, y)
        self.amount_of_calories = amount_of_calories


# Toxins
class ToxinZone(Agent):
    def __init__(self, unique_id, model, x, y, radius, intensity):
        super().__init__(unique_id, model)
        self.pos = (x, y)
        self.radius = radius
        self.intensity = intensity
        self.relative_intensity = 0


    def affects_cell(self, cell):
        distance = math.sqrt((self.pos[0] - cell.pos[0]) ** 2 + (self.pos[1] - cell.pos[1]) ** 2)
        self.relative_intensity =  self.intensity

        return distance <= self.radius


# Light Source
class LightSource(Agent):
    def __init__(self, unique_id, model, x, y, radious, intensity):
        super().__init__(unique_id, model)
        self.pos = (x, y)
        self.radious = radious
        self.intensity = intensity
        self.relative_intensity = 0

    def affects_cell(self, cell):
        # Calcula la distancia entre la fuente de luz y la célula usando distancia Euclidiana
        distance = math.sqrt((self.pos[0] - cell.pos[0]) ** 2 + (self.pos[1] - cell.pos[1]) ** 2)
        # Verifica si la célula está dentro del radio de acción
        # The maximum intensity a cell can receive is the value of intensity
        self.relative_intensity =  self.intensity
        return distance <= self.radious


# Extreme PH zone
class ExtremePH(Agent):
    def __init__(self, unique_id, model, x, y, radious, intensity):
        super().__init__(unique_id, model)
        self.pos = (x, y)
        self.radious = radious
        self.intensity = intensity
        self.relative_intensity = 0

    def affects_cell(self, cell):
        distance = math.sqrt((self.pos[0] - cell.pos[0]) ** 2 + (self.pos[1] - cell.pos[1]) ** 2)
        self.relative_intensity =  self.intensity * (self.radious/(distance + self.radious))

        return distance <= self.radious

# %% [markdown]
# ## Feedforward Neural Network Controller

# %%
class Feedforward():
    def __init__(self, layer_sizes, initial_weights=None):
        # Layer sizes is a vector which represent the size of each layer
        self.weights = []

        # Here specific weights are initialisized
        if initial_weights:
            self.weights = initial_weights
        else:
            # Here random weights are initialisized
            for i in range(len(layer_sizes) - 1):
                # Small values
                weight_matrix = np.random.randn(layer_sizes[i], layer_sizes[i + 1]) * 0.1
                self.weights.append(weight_matrix)

    def output(self, inputs):
        # This function calculates the output of the network
        # Through the dot product of the weights and the state of each neuron

        current_layer_output = inputs
        for weight_matrix in self.weights:
            current_layer_output = np.dot(current_layer_output, weight_matrix)
        return current_layer_output

# %% [markdown]
# ## Two-component Regulatory System Controller

# %%
class TCRS:
    def __init__(self, layer_sizes, initial_weights=None):
        self.layer_sizes = layer_sizes
        if initial_weights is not None:
            # Initial weights and layers sizes represent two layers, inputs and outputs
            self.sensor_weights = np.array(initial_weights[0])
            self.output_weights = np.array(initial_weights[1])
        else:
            # Initialisize with small random weights
            self.sensor_weights = np.random.randn(layer_sizes[0]) * 0.1
            self.output_weights = np.random.randn(layer_sizes[1]) * 0.1
        self.sensor_state = 0

        self.weights = [self.sensor_weights, self.output_weights]


    def sense(self, inputs):
        self.sensor_state = np.tanh(np.dot(inputs, self.sensor_weights))
        #print("self.sensor_state:", self.sensor_state)


    def regulate(self):
        e_x = np.exp(self.sensor_state * self.output_weights)
        #print("e_x:", e_x)
        return e_x / e_x.sum()

# %% [markdown]
# ## Cells

# %%
# Cellular Agent
class Cell(Agent):
    def __init__(self, unique_id, model, x, y, layer_sizes, mutation_rate_cells, controller, controller_state=None):
        super().__init__(unique_id, model)
        self.pos = (x,y)
        self.basal_metabolism = 2800
        self.calories = 3000
        self.fertility = 0
        self.toxins_disable_fertility = [False, 0]
        self.age = 0
        self.num_offspring = 0
        self.entropy = 10
        self.living = True
        self.fitness = 0
        self.max_entropy = 200
        self.time_alive = 0
        self.toxin_input = 0
        self.extreme_ph_input = 0
        self.light_input = 0
        self.glucose_input = 0
        self.mutation_rate_cells = mutation_rate_cells
        self.controller_state = controller_state
        self.layer_sizes = layer_sizes
        self.controller = controller
        self.neural_network = None
        self.TCRS_controller = None

    # Feedforward network or TCRS as a controller
    # Controller states assigns specific weights for the cell controller
    # Comment or discomment depending on what controller you want do use

        if self.controller == "TCRS":
                if controller_state != None:
                        self.TCRS_controller = TCRS(self.layer_sizes, controller_state)
                else:
                        self.TCRS_controller = TCRS(self.layer_sizes)
        else:
                if controller_state != None:
                    self.neural_network = Feedforward(self.layer_sizes, controller_state)
                else:
                    self.neural_network = Feedforward(self.layer_sizes)




    # Storing the controller of the cell
    def get_controller_state(self):
        return  self.TCRS_controller.weights if self.TCRS_controller != None else self.neural_network.weights


    def reproduce(self):
        # Create a new cell with the same properties
        child = Cell(self.model.next_id(), self.model, self.pos[0], self.pos[1], self.layer_sizes, self.mutation_rate_cells, self.controller)
        child.mutate()  # Apply mutations to the child
        return child


    def mutate(self):
        # For feedforward neural network
        mutation_rate = self.mutation_rate_cells  # Probability of mutation per weight
        mutation_strength = 0.12  # Magnitude of mutation

        if self.controller != "TCRS":
            for i in range(len(self.neural_network.weights)):
                if np.random.rand() < mutation_rate:
                    # Apply mutation as a random normal perturbation to the weights
                    noise = np.random.normal(0, mutation_strength, self.neural_network.weights[i].shape)
                    self.neural_network.weights[i] += noise
        else:
            for i in range(len(self.TCRS_controller.weights)):
                if np.random.rand() < mutation_rate:
                    # Apply mutation as a random normal perturbation to the weights
                    noise = np.random.normal(0, mutation_strength, self.TCRS_controller.weights[i].shape)
                    self.TCRS_controller.weights[i] += noise


    def is_fertil(self):
        # Habilita o deshabilita la fertilidad basada en la entropía y las calorías
        if (self.entropy > 50 and self.entropy < 180) and (self.calories > 800):
            self.fertility = 1
        else:
            self.fertility = 0



    def asexual_reproduction(self):
        self.entropy += 35
        self.calories -= 400
        self.num_offspring += 1


    def increase_entropy(self):
        # Entropy as the relationship between amount of calories needed for conserving its structure versus
        # the amount of calories the cell is able to obtain

        self.entropy += (self.basal_metabolism / (self.calories + 0.1))


    def toxins_fertility(self):
        if self.toxins_disable_fertility[0]:  # Si la fertilidad está deshabilitada
            time_disabled = self.time_alive - self.toxins_disable_fertility[1]
            if time_disabled >= 15:  # Si han pasado 15 o más pasos
                self.toxins_disable_fertility = [False, 0]
                self.fertility = 1  # Reactiva la fertilidad
            else:
                pass



    def check_toxin_zones(self):
        toxin_zones = [agent for agent in self.model.schedule.agents if isinstance(agent, ToxinZone)]

        # Check if cell is infected by toxins
        for zone in toxin_zones:
            if zone.affects_cell(self):
                if self.fertility == 1:
                    self.fertility = 0  # Cell loses reproduction capacity if is in toxin zone
                    self.toxins_disable_fertility = [True, self.time_alive]


                self.entropy  += zone.relative_intensity # Increasing entropy simulating stress due to toxin
                self.calories -= zone.relative_intensity # Spending energy to deal with toxin
                self.toxin_input = zone.relative_intensity # Senses toxin intensity

               # print("Entropy increasing due to Toxins")
                #print("Calories decreasing due to Toxins")


    def check_extreme_ph_zones(self):
        extreme_ph_zones = [agent for agent in self.model.schedule.agents if isinstance(agent, ExtremePH)]
        for zone in extreme_ph_zones:
            if zone.affects_cell(self):
                self.entropy += zone.relative_intensity # Velocity decreases
                self.extreme_ph_input = zone.relative_intensity # Senses PH intensity (acid or alkaline)
                #print("Self Speed has been change due to PH extreme zone")




    def check_light_sources(self):
        light_sources = [agent for agent in self.model.schedule.agents if isinstance(agent, LightSource)]
        for light in light_sources:
            if light.affects_cell(self):
                self.calories += light.relative_intensity  # Receive the amount of calories for the light
                self.light_input = light.relative_intensity # Senses the light intensity
                #print("Light Source giving some energy")
            else:
                pass


    def check_and_consume_glucose(self):
        # Check if there's glucose in the position
        contents = self.model.grid.get_cell_list_contents([self.pos])
        glucose_list = [obj for obj in contents if isinstance(obj, Glucose)]
        if len(glucose_list) > 0:
            # if so, sense the input, get the calories and remove the Glucose object
            for glucose in glucose_list:
                self.calories += glucose.amount_of_calories
                self.glucose_input = 1
                #print("Receiving Energy From Glucose")
                self.model.grid.remove_agent(glucose)
                self.model.schedule.remove(glucose)
        else:
            # Otherwise, the stimulus of glucose is 0
            self.glucose_input = 0


    def move(self, direction):
        # New position based on the direction
        delta = [(0, 1), (0, -1), (-1, 0), (1, 0)]  # Up, down, left, right
        new_x = self.pos[0] + delta[direction][0]
        new_y = self.pos[1] + delta[direction][1]

        # Check movement inside the world
        if 0 <= new_x < self.model.grid.width and 0 <= new_y < self.model.grid.height:
            # Comprueba si el agente aún está en la celda original antes de moverlo
            if self in self.model.grid.get_cell_list_contents([self.pos]):
                self.model.grid.move_agent(self, (new_x, new_y))



    def die(self):
        #if entropy is more than an specific limit, the cell dies
        if  self.entropy > self.max_entropy:
            self.living = False



    def fitness_measurement(self):
        weight_time_alive = 1
        weight_num_offsprings = 30
        #print("self fitness:", self.fitness)
        self.fitness = (weight_time_alive*self.time_alive) +  (weight_num_offsprings*self.num_offspring)



    def step(self):
        if self.living:
            self.check_toxin_zones()
            self.toxins_fertility()
            self.is_fertil()  # Updating fertility if is not in toxins zones
            self.check_extreme_ph_zones()
            self.check_light_sources()
            self.check_and_consume_glucose()

            # Inputs sensed by the cell
            inputs = np.array([self.glucose_input, self.light_input, self.extreme_ph_input, self.toxin_input, self.calories, self.entropy])

            if self.controller != "TCRS":
                # Feedforward Neural Network

                outputs = self.neural_network.output(inputs)
                move_direction = np.argmax(outputs[:4])  # Action based on the output of the network
                if outputs[move_direction] > 0.5:
                    self.move(move_direction)
                if outputs[4] > 0.5 and self.fertility:  # Decision of reproduction
                    self.asexual_reproduction()
            else:
                # Two Component Regulatory System
                self.TCRS_controller.sense(inputs)  # Receive signals from the environment
                outputs = self.TCRS_controller.regulate()  # Actions based on the output of the system

                # Choose based on the highest probability
                move_direction = np.argmax(outputs)

                #print("move direction:", move_direction)

                # Actions
                if move_direction < 4:
                    self.move(move_direction)
                elif move_direction == 4 and self.fertility:
                    self.asexual_reproduction()

            self.increase_entropy()
            self.time_alive += 1
            self.fitness_measurement()
            self.die()

# %% [markdown]
# ## Environment

# %%
class CellEnvironment(Model):
    def __init__(self, num_cells, num_food, num_light_sources, num_extreme_ph_zones, num_toxin_zones,
                 mutation_rate_cells, controller_state=None):
        super().__init__()
        width = 100
        height = 100
        self.grid = MultiGrid(width, height, True)
        self.schedule = RandomActivation(self)
        self.datacollector = DataCollector(
                    model_reporters={
                        "Average Fitness": get_fitness_avg,
                        "Fitness Std Dev": get_fitness_std,
                        "Average Lifespan": get_life_avg,
                        "Lifespan Std Dev": get_life_std,
                        "Average Offspring": get_offspring_avg,
                        "Offspring Std Dev": get_offspring_std,
                        "Average Fertility": get_fertility_avg,
                        "Fertility Std Dev": get_fertility_std
                    }
                )


               # Creating toxins
        for i in range(num_toxin_zones):
            x = self.random.randrange(0, 99)
            y = 0
            radius = self.random.randrange(5, 15)
            intensity = 1
            toxin_zone = ToxinZone(self.next_id() + i + 4000, self, x, y, radius, intensity)
            self.grid.place_agent(toxin_zone, (x, y))
            self.schedule.add(toxin_zone)



        # Creating extreme PH zones
        for i in range(num_extreme_ph_zones):
            x = self.random.randrange(0, 99)
            y = -5
            radious = 20
            intensity = 30
            extreme_ph_zone = ExtremePH(self.next_id() + i + 3000, self, x, y, radious, intensity)
            self.grid.place_agent(extreme_ph_zone, (x, y))
            self.schedule.add(extreme_ph_zone)


         # Creating light sources
        for i in range(num_light_sources):
            x = 10
            y = self.random.randrange(10, 90)
            #intensity = self.random.uniform(0, 0.9)
            intensity = 2
            radious = 15
            light_source = LightSource(self.next_id() + i + 2000, self, x, y, radious, intensity)
            self.grid.place_agent(light_source, (x, y))
            self.schedule.add(light_source)


        # Creating glucose sources
        for i in range(num_food):
            x = 99
            y = self.random.randrange(10, 90)
            amount_of_calories = 25
            glucose = Glucose(self.next_id() + i+ 1000, self, x, y, amount_of_calories)
            self.grid.place_agent(glucose, (x, y))
            self.schedule.add(glucose)


        # Creating Cells
        for i in range(num_cells):
            x = self.random.randrange(width)
            y = self.random.randrange(height)
            layer_sizes = [6,5,5]
            cell = Cell(self.next_id() + i, self, x, y, layer_sizes, mutation_rate_cells, "TCRS",  controller_state=controller_state)
            self.grid.place_agent(cell, (x, y))
            self.schedule.add(cell)


    def step(self):
        self.datacollector.collect(self)
        self.schedule.step()

# %% [markdown]
# # Evolution

# %% [markdown]
# ## Selection and mutation methods for the Genetic Algorithm

# %%
def selection_and_reproduction(model, desired_population_size):
    reproducers = [cell for cell in model.schedule.agents if isinstance(cell, Cell) and cell.num_offspring > 0]
    reproducers = sorted(reproducers, key=lambda x: (x.fitness, x.num_offspring), reverse=True)

    new_generation = []
    if not reproducers:
        return

    reproduction_rounds = max(cell.num_offspring for cell in reproducers)

    current_round = 1
    while len(new_generation) < desired_population_size:
        for cell in reproducers:
            if cell.num_offspring >= current_round:
                new_cell = cell.reproduce()
                new_generation.append(new_cell)
                if len(new_generation) == desired_population_size:
                    break
        if current_round == reproduction_rounds:
            current_round = 0
        current_round += 1

    cells_to_remove = [agent for agent in model.schedule.agents if isinstance(agent, Cell)]
    for cell in cells_to_remove:
        model.schedule.remove(cell)

    for new_agent in new_generation:
        model.schedule.add(new_agent)

# %% [markdown]
# ## Simulation

# %% [markdown]
#    Vectors to store useful information ----------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
number_of_cells_per_generation = []

average_fitness_per_generation = []
fitness_std_per_generation = []

average_lifespan_per_generation = []
lifespan_std_per_generation = []

average_num_offspring_per_generation = []
offspring_std_per_generation = []

weight_diversities_per_generation = []

# %% [markdown]
# Important parameters ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
num_steps_per_generation = 300
number_of_generations = 30
num_cells = 200
num_food =  100
num_light_sources = 5
num_extreme_ph_zones = 30
num_toxin_zones = 40
mutation_rate_cells = 0.15

# %% [markdown]
# Simulating the model ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Genetic Algorithm ---------------------------------------------------------------------------------

# Problems adding multiprocessing, but it's a good idea implemented here

model = CellEnvironment(num_cells, num_food, num_light_sources, num_extreme_ph_zones, num_toxin_zones,
                        mutation_rate_cells, controller_state=None)

for generation in range(number_of_generations):

    for i in range(num_steps_per_generation):
        model.step()

    selection_and_reproduction(model, num_cells)

    print(f"Generation {generation} data:",  model.datacollector.get_model_vars_dataframe().iloc[-1])

    generation_data = model.datacollector.get_model_vars_dataframe().iloc[-1]


    # Storing useful information per generation----------------------------------------------
    number_of_cells = len([cell for cell in model.schedule.agents if isinstance(cell, Cell)])
    number_of_cells_per_generation.append(number_of_cells)
    print("amount of cells:", number_of_cells)

    average_fitness_per_generation.append(generation_data['Average Fitness'])
    fitness_std_per_generation.append(generation_data['Fitness Std Dev'])

    average_lifespan_per_generation.append(generation_data['Average Lifespan'])
    lifespan_std_per_generation.append(generation_data['Lifespan Std Dev'])

    average_num_offspring_per_generation.append(generation_data['Average Offspring'])
    offspring_std_per_generation.append(generation_data['Offspring Std Dev'])


# Storing the best controller
best_controller = save_best_controller(model)
# Out:
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4001 is being placed with
# place_agent() despite already having the position (12, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4003 is being placed with
# place_agent() despite already having the position (44, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4005 is being placed with
# place_agent() despite already having the position (39, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4007 is being placed with
# place_agent() despite already having the position (58, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4009 is being placed with
# place_agent() despite already having the position (34, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4011 is being placed with
# place_agent() despite already having the position (78, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4013 is being placed with
# place_agent() despite already having the position (96, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4015 is being placed with
# place_agent() despite already having the position (41, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4017 is being placed with
# place_agent() despite already having the position (86, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4019 is being placed with
# place_agent() despite already having the position (43, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4021 is being placed with
# place_agent() despite already having the position (43, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4023 is being placed with
# place_agent() despite already having the position (23, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4025 is being placed with
# place_agent() despite already having the position (52, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4027 is being placed with
# place_agent() despite already having the position (56, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4029 is being placed with
# place_agent() despite already having the position (81, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4031 is being placed with
# place_agent() despite already having the position (5, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4033 is being placed with
# place_agent() despite already having the position (92, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4035 is being placed with
# place_agent() despite already having the position (45, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4037 is being placed with
# place_agent() despite already having the position (21, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4039 is being placed with
# place_agent() despite already having the position (51, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4041 is being placed with
# place_agent() despite already having the position (0, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4043 is being placed with
# place_agent() despite already having the position (93, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4045 is being placed with
# place_agent() despite already having the position (48, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4047 is being placed with
# place_agent() despite already having the position (82, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4049 is being placed with
# place_agent() despite already having the position (13, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4051 is being placed with
# place_agent() despite already having the position (52, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4053 is being placed with
# place_agent() despite already having the position (47, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4055 is being placed with
# place_agent() despite already having the position (45, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4057 is being placed with
# place_agent() despite already having the position (30, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4059 is being placed with
# place_agent() despite already having the position (45, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4061 is being placed with
# place_agent() despite already having the position (43, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4063 is being placed with
# place_agent() despite already having the position (83, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4065 is being placed with
# place_agent() despite already having the position (79, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4067 is being placed with
# place_agent() despite already having the position (55, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4069 is being placed with
# place_agent() despite already having the position (62, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4071 is being placed with
# place_agent() despite already having the position (93, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4073 is being placed with
# place_agent() despite already having the position (53, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4075 is being placed with
# place_agent() despite already having the position (31, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4077 is being placed with
# place_agent() despite already having the position (95, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:30: UserWarning: Agent 4079 is being placed with
# place_agent() despite already having the position (5, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3041 is being placed with
# place_agent() despite already having the position (51, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3043 is being placed with
# place_agent() despite already having the position (39, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3045 is being placed with
# place_agent() despite already having the position (36, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3047 is being placed with
# place_agent() despite already having the position (83, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3049 is being placed with
# place_agent() despite already having the position (90, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3051 is being placed with
# place_agent() despite already having the position (34, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3053 is being placed with
# place_agent() despite already having the position (44, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3055 is being placed with
# place_agent() despite already having the position (24, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3057 is being placed with
# place_agent() despite already having the position (74, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3059 is being placed with
# place_agent() despite already having the position (18, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3061 is being placed with
# place_agent() despite already having the position (10, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3063 is being placed with
# place_agent() despite already having the position (31, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3065 is being placed with
# place_agent() despite already having the position (39, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3067 is being placed with
# place_agent() despite already having the position (13, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3069 is being placed with
# place_agent() despite already having the position (14, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3071 is being placed with
# place_agent() despite already having the position (18, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3073 is being placed with
# place_agent() despite already having the position (56, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3075 is being placed with
# place_agent() despite already having the position (79, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3077 is being placed with
# place_agent() despite already having the position (30, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3079 is being placed with
# place_agent() despite already having the position (93, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3081 is being placed with
# place_agent() despite already having the position (74, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3083 is being placed with
# place_agent() despite already having the position (15, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3085 is being placed with
# place_agent() despite already having the position (97, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3087 is being placed with
# place_agent() despite already having the position (62, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3089 is being placed with
# place_agent() despite already having the position (74, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3091 is being placed with
# place_agent() despite already having the position (39, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3093 is being placed with
# place_agent() despite already having the position (68, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3095 is being placed with
# place_agent() despite already having the position (85, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3097 is being placed with
# place_agent() despite already having the position (44, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:42: UserWarning: Agent 3099 is being placed with
# place_agent() despite already having the position (82, -5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(extreme_ph_zone, (x, y))
# <ipython-input-9-681be04b827e>:54: UserWarning: Agent 2071 is being placed with
# place_agent() despite already having the position (10, 49). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(light_source, (x, y))
# <ipython-input-9-681be04b827e>:54: UserWarning: Agent 2073 is being placed with
# place_agent() despite already having the position (10, 63). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(light_source, (x, y))
# <ipython-input-9-681be04b827e>:54: UserWarning: Agent 2075 is being placed with
# place_agent() despite already having the position (10, 33). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(light_source, (x, y))
# <ipython-input-9-681be04b827e>:54: UserWarning: Agent 2077 is being placed with
# place_agent() despite already having the position (10, 71). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(light_source, (x, y))
# <ipython-input-9-681be04b827e>:54: UserWarning: Agent 2079 is being placed with
# place_agent() despite already having the position (10, 70). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(light_source, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1076 is being placed with
# place_agent() despite already having the position (99, 79). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1078 is being placed with
# place_agent() despite already having the position (99, 36). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1080 is being placed with
# place_agent() despite already having the position (99, 25). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1082 is being placed with
# place_agent() despite already having the position (99, 32). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1084 is being placed with
# place_agent() despite already having the position (99, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1086 is being placed with
# place_agent() despite already having the position (99, 44). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1088 is being placed with
# place_agent() despite already having the position (99, 49). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1090 is being placed with
# place_agent() despite already having the position (99, 28). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1092 is being placed with
# place_agent() despite already having the position (99, 63). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1094 is being placed with
# place_agent() despite already having the position (99, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1096 is being placed with
# place_agent() despite already having the position (99, 54). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1098 is being placed with
# place_agent() despite already having the position (99, 85). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1100 is being placed with
# place_agent() despite already having the position (99, 29). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1102 is being placed with
# place_agent() despite already having the position (99, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1104 is being placed with
# place_agent() despite already having the position (99, 30). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1106 is being placed with
# place_agent() despite already having the position (99, 30). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1108 is being placed with
# place_agent() despite already having the position (99, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1110 is being placed with
# place_agent() despite already having the position (99, 87). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1112 is being placed with
# place_agent() despite already having the position (99, 72). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1114 is being placed with
# place_agent() despite already having the position (99, 34). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1116 is being placed with
# place_agent() despite already having the position (99, 82). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1118 is being placed with
# place_agent() despite already having the position (99, 64). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1120 is being placed with
# place_agent() despite already having the position (99, 32). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1122 is being placed with
# place_agent() despite already having the position (99, 40). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1124 is being placed with
# place_agent() despite already having the position (99, 82). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1126 is being placed with
# place_agent() despite already having the position (99, 22). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1128 is being placed with
# place_agent() despite already having the position (99, 60). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1130 is being placed with
# place_agent() despite already having the position (99, 53). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1132 is being placed with
# place_agent() despite already having the position (99, 87). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1134 is being placed with
# place_agent() despite already having the position (99, 61). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1136 is being placed with
# place_agent() despite already having the position (99, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1138 is being placed with
# place_agent() despite already having the position (99, 20). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1140 is being placed with
# place_agent() despite already having the position (99, 70). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1142 is being placed with
# place_agent() despite already having the position (99, 22). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1144 is being placed with
# place_agent() despite already having the position (99, 85). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1146 is being placed with
# place_agent() despite already having the position (99, 44). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1148 is being placed with
# place_agent() despite already having the position (99, 75). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1150 is being placed with
# place_agent() despite already having the position (99, 45). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1152 is being placed with
# place_agent() despite already having the position (99, 66). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1154 is being placed with
# place_agent() despite already having the position (99, 75). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1156 is being placed with
# place_agent() despite already having the position (99, 78). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1158 is being placed with
# place_agent() despite already having the position (99, 75). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1160 is being placed with
# place_agent() despite already having the position (99, 31). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1162 is being placed with
# place_agent() despite already having the position (99, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1164 is being placed with
# place_agent() despite already having the position (99, 57). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1166 is being placed with
# place_agent() despite already having the position (99, 81). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1168 is being placed with
# place_agent() despite already having the position (99, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1170 is being placed with
# place_agent() despite already having the position (99, 74). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1172 is being placed with
# place_agent() despite already having the position (99, 58). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1174 is being placed with
# place_agent() despite already having the position (99, 57). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1176 is being placed with
# place_agent() despite already having the position (99, 75). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1178 is being placed with
# place_agent() despite already having the position (99, 64). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1180 is being placed with
# place_agent() despite already having the position (99, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1182 is being placed with
# place_agent() despite already having the position (99, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1184 is being placed with
# place_agent() despite already having the position (99, 42). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1186 is being placed with
# place_agent() despite already having the position (99, 61). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1188 is being placed with
# place_agent() despite already having the position (99, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1190 is being placed with
# place_agent() despite already having the position (99, 32). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1192 is being placed with
# place_agent() despite already having the position (99, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1194 is being placed with
# place_agent() despite already having the position (99, 46). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1196 is being placed with
# place_agent() despite already having the position (99, 38). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1198 is being placed with
# place_agent() despite already having the position (99, 78). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1200 is being placed with
# place_agent() despite already having the position (99, 71). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1202 is being placed with
# place_agent() despite already having the position (99, 51). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1204 is being placed with
# place_agent() despite already having the position (99, 26). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1206 is being placed with
# place_agent() despite already having the position (99, 76). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1208 is being placed with
# place_agent() despite already having the position (99, 60). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1210 is being placed with
# place_agent() despite already having the position (99, 42). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1212 is being placed with
# place_agent() despite already having the position (99, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1214 is being placed with
# place_agent() despite already having the position (99, 20). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1216 is being placed with
# place_agent() despite already having the position (99, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1218 is being placed with
# place_agent() despite already having the position (99, 83). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1220 is being placed with
# place_agent() despite already having the position (99, 82). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1222 is being placed with
# place_agent() despite already having the position (99, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1224 is being placed with
# place_agent() despite already having the position (99, 39). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1226 is being placed with
# place_agent() despite already having the position (99, 51). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1228 is being placed with
# place_agent() despite already having the position (99, 85). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1230 is being placed with
# place_agent() despite already having the position (99, 33). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1232 is being placed with
# place_agent() despite already having the position (99, 87). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1234 is being placed with
# place_agent() despite already having the position (99, 28). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1236 is being placed with
# place_agent() despite already having the position (99, 65). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1238 is being placed with
# place_agent() despite already having the position (99, 22). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1240 is being placed with
# place_agent() despite already having the position (99, 52). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1242 is being placed with
# place_agent() despite already having the position (99, 25). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1244 is being placed with
# place_agent() despite already having the position (99, 80). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1246 is being placed with
# place_agent() despite already having the position (99, 32). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1248 is being placed with
# place_agent() despite already having the position (99, 22). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1250 is being placed with
# place_agent() despite already having the position (99, 59). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1252 is being placed with
# place_agent() despite already having the position (99, 49). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(glucose, (x, y))
# <ipython-input-9-681be04b827e>:64: UserWarning: Agent 1254 is being placed with
# place_agent() despite already having the position (99, 68). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# ...
# <ipython-input-9-681be04b827e>:74: UserWarning: Agent 532 is being placed with
# place_agent() despite already having the position (2, 88). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-9-681be04b827e>:74: UserWarning: Agent 534 is being placed with
# place_agent() despite already having the position (55, 32). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-9-681be04b827e>:74: UserWarning: Agent 536 is being placed with
# place_agent() despite already having the position (86, 30). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-9-681be04b827e>:74: UserWarning: Agent 538 is being placed with
# place_agent() despite already having the position (1, 69). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-9-681be04b827e>:74: UserWarning: Agent 540 is being placed with
# place_agent() despite already having the position (16, 74). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-9-681be04b827e>:74: UserWarning: Agent 542 is being placed with
# place_agent() despite already having the position (87, 31). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-9-681be04b827e>:74: UserWarning: Agent 544 is being placed with
# place_agent() despite already having the position (50, 67). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-9-681be04b827e>:74: UserWarning: Agent 546 is being placed with
# place_agent() despite already having the position (25, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-9-681be04b827e>:74: UserWarning: Agent 548 is being placed with
# place_agent() despite already having the position (59, 49). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-9-681be04b827e>:74: UserWarning: Agent 550 is being placed with
# place_agent() despite already having the position (50, 75). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-9-681be04b827e>:74: UserWarning: Agent 552 is being placed with
# place_agent() despite already having the position (53, 71). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-9-681be04b827e>:74: UserWarning: Agent 554 is being placed with
# place_agent() despite already having the position (33, 41). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-9-681be04b827e>:74: UserWarning: Agent 556 is being placed with
# place_agent() despite already having the position (58, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-9-681be04b827e>:74: UserWarning: Agent 558 is being placed with
# place_agent() despite already having the position (34, 87). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-9-681be04b827e>:74: UserWarning: Agent 560 is being placed with
# place_agent() despite already having the position (42, 79). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-9-681be04b827e>:74: UserWarning: Agent 562 is being placed with
# place_agent() despite already having the position (3, 50). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-9-681be04b827e>:74: UserWarning: Agent 564 is being placed with
# place_agent() despite already having the position (72, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-9-681be04b827e>:74: UserWarning: Agent 566 is being placed with
# place_agent() despite already having the position (71, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-9-681be04b827e>:74: UserWarning: Agent 568 is being placed with
# place_agent() despite already having the position (69, 61). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-9-681be04b827e>:74: UserWarning: Agent 570 is being placed with
# place_agent() despite already having the position (86, 48). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-9-681be04b827e>:74: UserWarning: Agent 572 is being placed with
# place_agent() despite already having the position (75, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-9-681be04b827e>:74: UserWarning: Agent 574 is being placed with
# place_agent() despite already having the position (87, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# Generation 0 data: Average Fitness      146.240000
# Fitness Std Dev       81.321845
# Average Lifespan     123.290000
# Lifespan Std Dev      89.100819
# Average Offspring      0.765000
# Offspring Std Dev      1.536156
# Average Fertility      0.190000
# Fertility Std Dev      0.392301
# Name: 299, dtype: float64
# amount of cells: 200
# Generation 1 data: Average Fitness      188.240000
# Fitness Std Dev       52.386472
# Average Lifespan     163.490000
# Lifespan Std Dev      77.656036
# Average Offspring      0.825000
# Offspring Std Dev      1.604486
# Average Fertility      0.070000
# Fertility Std Dev      0.255147
# Name: 599, dtype: float64
# amount of cells: 200
# Generation 2 data: Average Fitness      199.450000
# Fitness Std Dev       22.898854
# Average Lifespan     174.100000
# Lifespan Std Dev      66.857685
# Average Offspring      0.845000
# Offspring Std Dev      1.628182
# Average Fertility      0.005000
# Fertility Std Dev      0.070534
# Name: 899, dtype: float64
# amount of cells: 200
# Generation 3 data: Average Fitness      202.750000
# Fitness Std Dev       23.518025
# Average Lifespan     184.750000
# Lifespan Std Dev      59.853968
# Average Offspring      0.600000
# Offspring Std Dev      1.428286
# Average Fertility      0.005000
# Fertility Std Dev      0.070534
# Name: 1199, dtype: float64
# amount of cells: 200
# Generation 4 data: Average Fitness      204.280000
# Fitness Std Dev       18.569103
# Average Lifespan     186.280000
# Lifespan Std Dev      58.529408
# Average Offspring      0.600000
# Offspring Std Dev      1.428286
# Average Fertility      0.000000
# Fertility Std Dev      0.000000
# Name: 1499, dtype: float64
# amount of cells: 200
# Generation 5 data: Average Fitness      201.860000
# Fitness Std Dev       21.069419
# Average Lifespan     173.960000
# Lifespan Std Dev      69.045625
# Average Offspring      0.930000
# Offspring Std Dev      1.683776
# Average Fertility      0.005000
# Fertility Std Dev      0.070534
# Name: 1799, dtype: float64
# amount of cells: 200
# Generation 6 data: Average Fitness      204.815000
# Fitness Std Dev       20.887575
# Average Lifespan     182.765000
# Lifespan Std Dev      64.213159
# Average Offspring      0.735000
# Offspring Std Dev      1.544272
# Average Fertility      0.000000
# Fertility Std Dev      0.000000
# Name: 2099, dtype: float64
# amount of cells: 200
# Generation 7 data: Average Fitness      205.475000
# Fitness Std Dev       21.915505
# Average Lifespan     181.925000
# Lifespan Std Dev      66.183528
# Average Offspring      0.785000
# Offspring Std Dev      1.577585
# Average Fertility      0.000000
# Fertility Std Dev      0.000000
# Name: 2399, dtype: float64
# amount of cells: 200
# Generation 8 data: Average Fitness      208.585000
# Fitness Std Dev       22.946302
# Average Lifespan     186.535000
# Lifespan Std Dev      65.878136
# Average Offspring      0.735000
# Offspring Std Dev      1.537782
# Average Fertility      0.000000
# Fertility Std Dev      0.000000
# Name: 2699, dtype: float64
# amount of cells: 200
# Generation 9 data: Average Fitness      207.000000
# Fitness Std Dev       23.020643
# Average Lifespan     182.250000
# Lifespan Std Dev      68.374612
# Average Offspring      0.825000
# Offspring Std Dev      1.613808
# Average Fertility      0.000000
# Fertility Std Dev      0.000000
# Name: 2999, dtype: float64
# amount of cells: 200
# Generation 10 data: Average Fitness      208.670000
# Fitness Std Dev       24.766936
# Average Lifespan     181.970000
# Lifespan Std Dev      71.631621
# Average Offspring      0.890000
# Offspring Std Dev      1.657679
# Average Fertility      0.000000
# Fertility Std Dev      0.000000
# Name: 3299, dtype: float64
# amount of cells: 200
# Generation 11 data: Average Fitness      212.290000
# Fitness Std Dev       22.852262
# Average Lifespan     193.540000
# Lifespan Std Dev      62.931220
# Average Offspring      0.625000
# Offspring Std Dev      1.447196
# Average Fertility      0.000000
# Fertility Std Dev      0.000000
# Name: 3599, dtype: float64
# amount of cells: 200
# Generation 12 data: Average Fitness      212.410000
# Fitness Std Dev       24.024194
# Average Lifespan     191.110000
# Lifespan Std Dev      66.549515
# Average Offspring      0.710000
# Offspring Std Dev      1.518519
# Average Fertility      0.000000
# Fertility Std Dev      0.000000
# Name: 3899, dtype: float64
# amount of cells: 200
# Generation 13 data: Average Fitness      213.370000
# Fitness Std Dev       25.829694
# Average Lifespan     187.870000
# Lifespan Std Dev      71.871365
# Average Offspring      0.850000
# Offspring Std Dev      1.611676
# Average Fertility      0.005000
# Fertility Std Dev      0.070534
# Name: 4199, dtype: float64
# amount of cells: 200
# Generation 14 data: Average Fitness      215.230000
# Fitness Std Dev       24.779570
# Average Lifespan     193.030000
# Lifespan Std Dev      68.649101
# Average Offspring      0.740000
# Offspring Std Dev      1.543503
# Average Fertility      0.000000
# Fertility Std Dev      0.000000
# Name: 4499, dtype: float64
# amount of cells: 200
# Generation 15 data: Average Fitness      214.555000
# Fitness Std Dev       26.112774
# Average Lifespan     188.305000
# Lifespan Std Dev      73.603342
# Average Offspring      0.875000
# Offspring Std Dev      1.649053
# Average Fertility      0.000000
# Fertility Std Dev      0.000000
# Name: 4799, dtype: float64
# amount of cells: 200
# Generation 16 data: Average Fitness      215.085000
# Fitness Std Dev       25.527980
# Average Lifespan     190.485000
# Lifespan Std Dev      71.843579
# Average Offspring      0.820000
# Offspring Std Dev      1.614806
# Average Fertility      0.000000
# Fertility Std Dev      0.000000
# Name: 5099, dtype: float64
# amount of cells: 200
# Generation 17 data: Average Fitness      215.205000
# Fitness Std Dev       25.996595
# Average Lifespan     190.005000
# Lifespan Std Dev      72.457677
# Average Offspring      0.840000
# Offspring Std Dev      1.613815
# Average Fertility      0.000000
# Fertility Std Dev      0.000000
# Name: 5399, dtype: float64
# amount of cells: 200
# Generation 18 data: Average Fitness      212.890000
# Fitness Std Dev       25.108124
# Average Lifespan     188.890000
# Lifespan Std Dev      70.003128
# Average Offspring      0.800000
# Offspring Std Dev      1.584298
# Average Fertility      0.000000
# Fertility Std Dev      0.000000
# Name: 5699, dtype: float64
# amount of cells: 200
# Generation 19 data: Average Fitness      215.685000
# Fitness Std Dev       24.204251
# Average Lifespan     194.685000
# Lifespan Std Dev      67.213211
# Average Offspring      0.700000
# Offspring Std Dev      1.519868
# Average Fertility      0.000000
# Fertility Std Dev      0.000000
# Name: 5999, dtype: float64
# amount of cells: 200
# Generation 20 data: Average Fitness      216.525000
# Fitness Std Dev       26.927298
# Average Lifespan     188.025000
# Lifespan Std Dev      76.585602
# Average Offspring      0.950000
# Offspring Std Dev      1.693369
# Average Fertility      0.000000
# Fertility Std Dev      0.000000
# Name: 6299, dtype: float64
# amount of cells: 200
# Generation 21 data: Average Fitness      222.695000
# Fitness Std Dev       23.385294
# Average Lifespan     204.095000
# Lifespan Std Dev      65.504702
# Average Offspring      0.620000
# Offspring Std Dev      1.437220
# Average Fertility      0.000000
# Fertility Std Dev      0.000000
# Name: 6599, dtype: float64
# amount of cells: 200
# Generation 22 data: Average Fitness      220.195000
# Fitness Std Dev       26.289674
# Average Lifespan     193.645000
# Lifespan Std Dev      75.213024
# Average Offspring      0.885000
# Offspring Std Dev      1.640663
# Average Fertility      0.005000
# Fertility Std Dev      0.070534
# Name: 6899, dtype: float64
# amount of cells: 200
# Generation 23 data: Average Fitness      221.755000
# Fitness Std Dev       25.097310
# Average Lifespan     198.505000
# Lifespan Std Dev      71.815876
# Average Offspring      0.775000
# Offspring Std Dev      1.569833
# Average Fertility      0.000000
# Fertility Std Dev      0.000000
# Name: 7199, dtype: float64
# amount of cells: 200
# Generation 24 data: Average Fitness      222.585000
# Fitness Std Dev       24.353086
# Average Lifespan     201.435000
# Lifespan Std Dev      69.388729
# Average Offspring      0.705000
# Offspring Std Dev      1.519202
# Average Fertility      0.000000
# Fertility Std Dev      0.000000
# Name: 7499, dtype: float64
# amount of cells: 200
# Generation 25 data: Average Fitness      222.590000
# Fitness Std Dev       24.144604
# Average Lifespan     202.040000
# Lifespan Std Dev      68.536183
# Average Offspring      0.685000
# Offspring Std Dev      1.501924
# Average Fertility      0.000000
# Fertility Std Dev      0.000000
# Name: 7799, dtype: float64
# amount of cells: 200
# Generation 26 data: Average Fitness      220.110000
# Fitness Std Dev       26.334538
# Average Lifespan     194.160000
# Lifespan Std Dev      74.958084
# Average Offspring      0.865000
# Offspring Std Dev      1.636085
# Average Fertility      0.005000
# Fertility Std Dev      0.070534
# Name: 8099, dtype: float64
# amount of cells: 200
# Generation 27 data: Average Fitness      219.215000
# Fitness Std Dev       25.901328
# Average Lifespan     194.015000
# Lifespan Std Dev      73.874724
# Average Offspring      0.840000
# Offspring Std Dev      1.629233
# Average Fertility      0.005000
# Fertility Std Dev      0.070534
# Name: 8399, dtype: float64
# amount of cells: 200
# Generation 28 data: Average Fitness      218.905000
# Fitness Std Dev       25.513251
# Average Lifespan     194.455000
# Lifespan Std Dev      72.375258
# Average Offspring      0.815000
# Offspring Std Dev      1.600242
# Average Fertility      0.005000
# Fertility Std Dev      0.070534
# Name: 8699, dtype: float64
# amount of cells: 200
# Generation 29 data: Average Fitness      220.760000
# Fitness Std Dev       24.454701
# Average Lifespan     199.310000
# Lifespan Std Dev      69.159482
# Average Offspring      0.715000
# Offspring Std Dev      1.527670
# Average Fertility      0.000000
# Fertility Std Dev      0.000000
# Name: 8999, dtype: float64
# amount of cells: 200

# %% [markdown]
# ## Visualization of metrics

# %%
max_fitness = model.datacollector.get_model_vars_dataframe()['Average Fitness'].max()
print("The max fitness achieved is:", max_fitness)
# Out:
# The max fitness achieved is: 222.695

# %%
plt.figure(figsize=(12, 20))

generations = [i for i in range(number_of_generations)]

# Average fitness per generation
plt.subplot(6, 2, 1)  # Esto crea un subplot en una grilla de 2x2 en la posición 2
plt.plot(average_fitness_per_generation, label='Average Fitness')
plt.fill_between(range(len(fitness_std_per_generation)),
                 [a - b for a, b in zip(average_fitness_per_generation, fitness_std_per_generation)],
                 [a + b for a, b in zip(average_fitness_per_generation, fitness_std_per_generation)],
                 color='blue', alpha=0.1)
plt.xlabel('Generation')
plt.ylabel('Average Fitness')
min_fitness = min(average_fitness_per_generation)
max_fitness = max(average_fitness_per_generation)
plt.ylim([min_fitness - 10, max_fitness  + 10])
plt.title('Average Fitness over Generations')
plt.legend()


# Average standard deviation fitness per generation
plt.subplot(6, 2, 2)
plt.plot(generations, fitness_std_per_generation, label='Fitness Std Dev')
plt.xlabel('Generation')
plt.ylabel('Fitness Std Dev')
min_fitness = min(fitness_std_per_generation)
max_fitness = max(fitness_std_per_generation)
plt.ylim([min_fitness - 10, max_fitness  + 10])
plt.title('Fitness Standard Deviation over Generations')
plt.legend()



# Average lifespan per generation
plt.subplot(6, 2, 3)  # Esto crea un subplot en una grilla de 2x2 en la posición 3
plt.plot(average_lifespan_per_generation, label='Average Lifespan')
plt.fill_between(range(len(lifespan_std_per_generation)),
                 [a - b for a, b in zip(average_lifespan_per_generation, lifespan_std_per_generation)],
                 [a + b for a, b in zip(average_lifespan_per_generation, lifespan_std_per_generation)],
                 color='orange', alpha=0.1)
plt.xlabel('Generation')
plt.ylabel('Average Lifespan')
min_fitness = min(average_lifespan_per_generation)
max_fitness = max(average_lifespan_per_generation)
plt.ylim([min_fitness - 10, max_fitness  + 10])
plt.title('Average Lifespan over Generations')
plt.legend()


# Average lifespan standard deviation per generation
plt.subplot(6, 2, 4)
plt.plot(generations, lifespan_std_per_generation, label='Lifespan Std Dev')
plt.xlabel('Generation')
plt.ylabel('Lifespan Std Dev')
min_fitness = min(lifespan_std_per_generation)
max_fitness = max(lifespan_std_per_generation)
plt.ylim([min_fitness - 10, max_fitness  + 10])
plt.title('Lifespan Standard Deviation over Generations')
plt.legend()



# Average offsprings per generation
plt.subplot(6, 2, 5)  # Esto crea un subplot en una grilla de 2x2 en la posición 4
plt.plot(average_num_offspring_per_generation, label='Average Num Offspring')
plt.fill_between(range(len(offspring_std_per_generation)),
                 [a - b for a, b in zip(average_num_offspring_per_generation, offspring_std_per_generation)],
                 [a + b for a, b in zip(average_num_offspring_per_generation, offspring_std_per_generation)],
                 color='green', alpha=0.1)
plt.xlabel('Generation')
plt.ylabel('Average Num Offspring')
min_fitness = min(average_num_offspring_per_generation)
max_fitness = max(average_num_offspring_per_generation)
plt.ylim([min_fitness - 0.5, max_fitness  + 0.5])
plt.title('Average Num Offspring over Generations')
plt.legend()


# Average standard deviation offsprings per generation
plt.subplot(6, 2, 6)
plt.plot(generations, offspring_std_per_generation, label='Offspring Std Dev')
plt.xlabel('Generation')
plt.ylabel('Offspring Std Dev')
min_fitness = min(offspring_std_per_generation)
max_fitness = max(offspring_std_per_generation)
plt.ylim([min_fitness - 0.5, max_fitness  + 0.5])
plt.title('Offspring Standard Deviation over Generations')
plt.legend()

# Ajusta los subplots para que no se superpongan
plt.tight_layout()

plt.savefig('mi_grafica.png')

plt.show()

# %% [markdown]
# ## Visualization of the behaviour of a generation in real time

# %%
def agent_portrayal(agent):
    portrayal = {"Shape": "circle", "Filled": "false", "Layer": 0, "r": 0.8}
    if isinstance(agent, Cell):
        portrayal["Color"] = "blue" if agent.living else "red"
        portrayal["Layer"] = 2
    elif isinstance(agent, Glucose):
        portrayal["Color"] = "green"
        portrayal["Layer"] = 1
    elif isinstance(agent, LightSource):
        portrayal["Color"] = "yellow"
        portrayal["Layer"] = 1
        portrayal["r"] = agent.radious
    elif isinstance(agent, ExtremePH):
        portrayal["Color"] = "brown"
        portrayal["Layer"] = 1
        portrayal["r"] = agent.radious
    elif isinstance(agent, ToxinZone):
        portrayal["Color"] = "#EF5E00"
        portrayal["Layer"] = 1
        portrayal["r"] = agent.radius


    return portrayal

# %%
best_controller
# Out:
# [array([-0.05535883,  0.0301562 ,  0.15221067, -0.04217984,  0.10910533,
#          0.00740326]),
#  array([ 0.01631783,  0.15516716, -0.13834454,  0.02426901, -0.00249763])]

# %%
grid = CanvasGrid(agent_portrayal, 100, 100, 800, 800)

entropy_chart = ChartModule([{"Label": "Entropy", "Color": "Red"}], data_collector_name='datacollector')
calories_chart = ChartModule([{"Label": "Calories", "Color": "Green"}], data_collector_name='datacollector')

server = ModularServer(CellEnvironment,
                       [grid, entropy_chart, calories_chart],
                       "Cell Environment",
                       {"num_cells": 100, "num_food": 100, "num_light_sources": 40, "num_extreme_ph_zones": 40,
                        "num_toxin_zones": 40,"mutation_rate_cells": mutation_rate_cells, "controller_state": best_controller})
server.launch()
# Out:
# Interface starting at http://127.0.0.1:8521
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4001 is being placed with
# place_agent() despite already having the position (98, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5002 is being placed with
# place_agent() despite already having the position (34, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6003 is being placed with
# place_agent() despite already having the position (5, 22). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7004 is being placed with
# place_agent() despite already having the position (99, 40). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4006 is being placed with
# place_agent() despite already having the position (96, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5007 is being placed with
# place_agent() despite already having the position (38, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6008 is being placed with
# place_agent() despite already having the position (5, 85). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7009 is being placed with
# place_agent() despite already having the position (99, 74). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4011 is being placed with
# place_agent() despite already having the position (46, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5012 is being placed with
# place_agent() despite already having the position (30, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6013 is being placed with
# place_agent() despite already having the position (5, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7014 is being placed with
# place_agent() despite already having the position (99, 21). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4016 is being placed with
# place_agent() despite already having the position (61, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5017 is being placed with
# place_agent() despite already having the position (50, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6018 is being placed with
# place_agent() despite already having the position (5, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7019 is being placed with
# place_agent() despite already having the position (99, 64). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4021 is being placed with
# place_agent() despite already having the position (17, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5022 is being placed with
# place_agent() despite already having the position (75, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6023 is being placed with
# place_agent() despite already having the position (5, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7024 is being placed with
# place_agent() despite already having the position (99, 21). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4026 is being placed with
# place_agent() despite already having the position (41, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5027 is being placed with
# place_agent() despite already having the position (3, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6028 is being placed with
# place_agent() despite already having the position (5, 32). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7029 is being placed with
# place_agent() despite already having the position (99, 60). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4031 is being placed with
# place_agent() despite already having the position (81, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5032 is being placed with
# place_agent() despite already having the position (23, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6033 is being placed with
# place_agent() despite already having the position (5, 23). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7034 is being placed with
# place_agent() despite already having the position (99, 38). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4036 is being placed with
# place_agent() despite already having the position (14, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5037 is being placed with
# place_agent() despite already having the position (61, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6038 is being placed with
# place_agent() despite already having the position (5, 89). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7039 is being placed with
# place_agent() despite already having the position (99, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4041 is being placed with
# place_agent() despite already having the position (73, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5042 is being placed with
# place_agent() despite already having the position (98, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6043 is being placed with
# place_agent() despite already having the position (5, 73). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7044 is being placed with
# place_agent() despite already having the position (99, 29). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4046 is being placed with
# place_agent() despite already having the position (1, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5047 is being placed with
# place_agent() despite already having the position (30, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6048 is being placed with
# place_agent() despite already having the position (5, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7049 is being placed with
# place_agent() despite already having the position (99, 86). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4051 is being placed with
# place_agent() despite already having the position (3, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5052 is being placed with
# place_agent() despite already having the position (29, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6053 is being placed with
# place_agent() despite already having the position (5, 66). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7054 is being placed with
# place_agent() despite already having the position (99, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4056 is being placed with
# place_agent() despite already having the position (51, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5057 is being placed with
# place_agent() despite already having the position (52, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6058 is being placed with
# place_agent() despite already having the position (5, 20). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7059 is being placed with
# place_agent() despite already having the position (99, 22). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4061 is being placed with
# place_agent() despite already having the position (70, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5062 is being placed with
# place_agent() despite already having the position (57, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6063 is being placed with
# place_agent() despite already having the position (5, 73). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7064 is being placed with
# place_agent() despite already having the position (99, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4066 is being placed with
# place_agent() despite already having the position (11, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5067 is being placed with
# place_agent() despite already having the position (42, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6068 is being placed with
# place_agent() despite already having the position (5, 98). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7069 is being placed with
# place_agent() despite already having the position (99, 37). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4071 is being placed with
# place_agent() despite already having the position (17, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5072 is being placed with
# place_agent() despite already having the position (45, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6073 is being placed with
# place_agent() despite already having the position (5, 57). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7074 is being placed with
# place_agent() despite already having the position (99, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4076 is being placed with
# place_agent() despite already having the position (38, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5077 is being placed with
# place_agent() despite already having the position (53, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6078 is being placed with
# place_agent() despite already having the position (5, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7079 is being placed with
# place_agent() despite already having the position (99, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4081 is being placed with
# place_agent() despite already having the position (82, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5082 is being placed with
# place_agent() despite already having the position (65, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6083 is being placed with
# place_agent() despite already having the position (5, 77). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7084 is being placed with
# place_agent() despite already having the position (99, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4086 is being placed with
# place_agent() despite already having the position (77, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5087 is being placed with
# place_agent() despite already having the position (29, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6088 is being placed with
# place_agent() despite already having the position (5, 20). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7089 is being placed with
# place_agent() despite already having the position (99, 80). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4091 is being placed with
# place_agent() despite already having the position (98, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5092 is being placed with
# place_agent() despite already having the position (37, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6093 is being placed with
# place_agent() despite already having the position (5, 20). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7094 is being placed with
# place_agent() despite already having the position (99, 43). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4096 is being placed with
# place_agent() despite already having the position (38, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5097 is being placed with
# place_agent() despite already having the position (95, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6098 is being placed with
# place_agent() despite already having the position (5, 54). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7099 is being placed with
# place_agent() despite already having the position (99, 58). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4101 is being placed with
# place_agent() despite already having the position (34, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5102 is being placed with
# place_agent() despite already having the position (67, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6103 is being placed with
# place_agent() despite already having the position (5, 90). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7104 is being placed with
# place_agent() despite already having the position (99, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4106 is being placed with
# place_agent() despite already having the position (38, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5107 is being placed with
# place_agent() despite already having the position (64, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6108 is being placed with
# place_agent() despite already having the position (5, 31). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7109 is being placed with
# place_agent() despite already having the position (99, 25). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4111 is being placed with
# place_agent() despite already having the position (70, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5112 is being placed with
# place_agent() despite already having the position (39, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6113 is being placed with
# place_agent() despite already having the position (5, 36). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7114 is being placed with
# place_agent() despite already having the position (99, 59). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4116 is being placed with
# place_agent() despite already having the position (78, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5117 is being placed with
# place_agent() despite already having the position (45, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6118 is being placed with
# place_agent() despite already having the position (5, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7119 is being placed with
# place_agent() despite already having the position (99, 97). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4121 is being placed with
# place_agent() despite already having the position (41, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5122 is being placed with
# place_agent() despite already having the position (6, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6123 is being placed with
# place_agent() despite already having the position (5, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7124 is being placed with
# place_agent() despite already having the position (99, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4126 is being placed with
# place_agent() despite already having the position (72, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5127 is being placed with
# place_agent() despite already having the position (34, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6128 is being placed with
# place_agent() despite already having the position (5, 33). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7129 is being placed with
# place_agent() despite already having the position (99, 61). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4131 is being placed with
# place_agent() despite already having the position (2, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5132 is being placed with
# place_agent() despite already having the position (63, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6133 is being placed with
# place_agent() despite already having the position (5, 28). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7134 is being placed with
# place_agent() despite already having the position (99, 36). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4136 is being placed with
# place_agent() despite already having the position (64, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5137 is being placed with
# place_agent() despite already having the position (57, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6138 is being placed with
# place_agent() despite already having the position (5, 99). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7139 is being placed with
# place_agent() despite already having the position (99, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4141 is being placed with
# place_agent() despite already having the position (3, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5142 is being placed with
# place_agent() despite already having the position (77, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6143 is being placed with
# place_agent() despite already having the position (5, 97). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7144 is being placed with
# place_agent() despite already having the position (99, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4146 is being placed with
# place_agent() despite already having the position (2, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5147 is being placed with
# place_agent() despite already having the position (34, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6148 is being placed with
# place_agent() despite already having the position (5, 39). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7149 is being placed with
# place_agent() despite already having the position (99, 23). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4151 is being placed with
# place_agent() despite already having the position (44, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5152 is being placed with
# place_agent() despite already having the position (93, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6153 is being placed with
# place_agent() despite already having the position (5, 60). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7154 is being placed with
# place_agent() despite already having the position (99, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4156 is being placed with
# place_agent() despite already having the position (53, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5157 is being placed with
# place_agent() despite already having the position (40, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6158 is being placed with
# place_agent() despite already having the position (5, 25). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7159 is being placed with
# place_agent() despite already having the position (99, 65). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4161 is being placed with
# place_agent() despite already having the position (66, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5162 is being placed with
# place_agent() despite already having the position (93, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6163 is being placed with
# place_agent() despite already having the position (5, 33). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7164 is being placed with
# place_agent() despite already having the position (99, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4166 is being placed with
# place_agent() despite already having the position (85, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5167 is being placed with
# place_agent() despite already having the position (77, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6168 is being placed with
# place_agent() despite already having the position (5, 93). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7169 is being placed with
# place_agent() despite already having the position (99, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4171 is being placed with
# place_agent() despite already having the position (83, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5172 is being placed with
# place_agent() despite already having the position (68, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6173 is being placed with
# place_agent() despite already having the position (5, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7174 is being placed with
# place_agent() despite already having the position (99, 31). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4176 is being placed with
# place_agent() despite already having the position (92, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5177 is being placed with
# place_agent() despite already having the position (9, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6178 is being placed with
# place_agent() despite already having the position (5, 58). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7179 is being placed with
# place_agent() despite already having the position (99, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4181 is being placed with
# place_agent() despite already having the position (62, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5182 is being placed with
# place_agent() despite already having the position (61, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6183 is being placed with
# place_agent() despite already having the position (5, 38). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7184 is being placed with
# place_agent() despite already having the position (99, 39). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4186 is being placed with
# place_agent() despite already having the position (27, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5187 is being placed with
# place_agent() despite already having the position (17, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6188 is being placed with
# place_agent() despite already having the position (5, 82). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# <ipython-input-79-555f86097c32>:52: UserWarning: Agent 7189 is being placed with
# place_agent() despite already having the position (99, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_right, (x_right, y_right))
# <ipython-input-79-555f86097c32>:31: UserWarning: Agent 4191 is being placed with
# place_agent() despite already having the position (65, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_top, (x_top, y_top))
# <ipython-input-79-555f86097c32>:38: UserWarning: Agent 5192 is being placed with
# place_agent() despite already having the position (64, 94). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_bottom, (x_bottom, y_bottom))
# <ipython-input-79-555f86097c32>:45: UserWarning: Agent 6193 is being placed with
# place_agent() despite already having the position (5, 51). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(toxin_zone_left, (x_left, y_left))
# ...
# place_agent() despite already having the position (25, 84). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 403 is being placed with
# place_agent() despite already having the position (86, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 405 is being placed with
# place_agent() despite already having the position (5, 21). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 407 is being placed with
# place_agent() despite already having the position (6, 32). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 409 is being placed with
# place_agent() despite already having the position (53, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 411 is being placed with
# place_agent() despite already having the position (21, 31). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 413 is being placed with
# place_agent() despite already having the position (91, 95). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 415 is being placed with
# place_agent() despite already having the position (24, 75). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 417 is being placed with
# place_agent() despite already having the position (47, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 419 is being placed with
# place_agent() despite already having the position (76, 93). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 421 is being placed with
# place_agent() despite already having the position (94, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 423 is being placed with
# place_agent() despite already having the position (21, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 425 is being placed with
# place_agent() despite already having the position (50, 99). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 427 is being placed with
# place_agent() despite already having the position (44, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 429 is being placed with
# place_agent() despite already having the position (99, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 431 is being placed with
# place_agent() despite already having the position (8, 42). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 433 is being placed with
# place_agent() despite already having the position (37, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 435 is being placed with
# place_agent() despite already having the position (58, 66). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 437 is being placed with
# place_agent() despite already having the position (62, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 439 is being placed with
# place_agent() despite already having the position (13, 98). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 441 is being placed with
# place_agent() despite already having the position (16, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 443 is being placed with
# place_agent() despite already having the position (61, 83). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 445 is being placed with
# place_agent() despite already having the position (70, 95). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 447 is being placed with
# place_agent() despite already having the position (74, 35). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 449 is being placed with
# place_agent() despite already having the position (12, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 451 is being placed with
# place_agent() despite already having the position (53, 29). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 453 is being placed with
# place_agent() despite already having the position (17, 62). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 455 is being placed with
# place_agent() despite already having the position (7, 40). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 457 is being placed with
# place_agent() despite already having the position (39, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 459 is being placed with
# place_agent() despite already having the position (8, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 461 is being placed with
# place_agent() despite already having the position (25, 52). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 463 is being placed with
# place_agent() despite already having the position (98, 95). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 465 is being placed with
# place_agent() despite already having the position (8, 44). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 467 is being placed with
# place_agent() despite already having the position (69, 26). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 469 is being placed with
# place_agent() despite already having the position (82, 53). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 471 is being placed with
# place_agent() despite already having the position (7, 78). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 473 is being placed with
# place_agent() despite already having the position (78, 33). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 475 is being placed with
# place_agent() despite already having the position (9, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 477 is being placed with
# place_agent() despite already having the position (65, 23). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 479 is being placed with
# place_agent() despite already having the position (3, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 481 is being placed with
# place_agent() despite already having the position (73, 38). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 483 is being placed with
# place_agent() despite already having the position (27, 33). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 485 is being placed with
# place_agent() despite already having the position (71, 29). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 487 is being placed with
# place_agent() despite already having the position (7, 32). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 489 is being placed with
# place_agent() despite already having the position (31, 39). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 491 is being placed with
# place_agent() despite already having the position (25, 54). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 493 is being placed with
# place_agent() despite already having the position (23, 50). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 495 is being placed with
# place_agent() despite already having the position (99, 45). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 497 is being placed with
# place_agent() despite already having the position (23, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# <ipython-input-79-555f86097c32>:88: UserWarning: Agent 499 is being placed with
# place_agent() despite already having the position (94, 67). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(cell, (x, y))
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-89-4c28abb6b93f> in <cell line: 11>()
#       9                        {"num_cells": 100, "num_food": 100, "num_light_sources": 40, "num_extreme_ph_zones": 40,
#      10                         "num_toxin_zones": 40,"mutation_rate_cells": mutation_rate_cells, "controller_state": best_controller})
# ---> 11 server.launch()
#
# /usr/local/lib/python3.10/dist-packages/mesa_viz_tornado/ModularVisualization.py in launch(self, port, open_browser)
#     400         url = f"http://127.0.0.1:{self.port}"
#     401         print(f"Interface starting at {url}")
# --> 402         self.listen(self.port)
#     403         if open_browser:
#     404             webbrowser.open(url)
#
# /usr/local/lib/python3.10/dist-packages/tornado/web.py in listen(self, port, address, family, backlog, flags, reuse_port, **kwargs)
#    2205         """
#    2206         server = HTTPServer(self, **kwargs)
# -> 2207         server.listen(
#    2208             port,
#    2209             address=address,
#
# /usr/local/lib/python3.10/dist-packages/tornado/tcpserver.py in listen(self, port, address, family, backlog, flags, reuse_port)
#     181            arguments to match `tornado.netutil.bind_sockets`.
#     182         """
# --> 183         sockets = bind_sockets(
#     184             port,
#     185             address=address,
#
# /usr/local/lib/python3.10/dist-packages/tornado/netutil.py in bind_sockets(port, address, family, backlog, flags, reuse_port)
#     160         sock.setblocking(False)
#     161         try:
# --> 162             sock.bind(sockaddr)
#     163         except OSError as e:
#     164             if (
#
# OSError: [Errno 98] Address already in use
